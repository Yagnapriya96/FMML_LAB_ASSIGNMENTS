# %% [markdown]
# <a href="https://colab.research.google.com/github/Yagnapriya96/FMML_LAB_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-29 07:28:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   200MB/s    in 0.3s
#
# 2024-03-29 07:28:08 (200 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 20719  1611.04146v2  In this paper, we propose commonsense knowledg...    cs
# 3188    1206.6437v1  Natural image statistics exhibit hierarchical ...    cs
# 9369   1512.01272v1  There is a widespread need for statistical met...    cs
# 31860   1106.3397v1  This paper addresses the pattern classificatio...    cs
# 11029   1311.2971v1  Determinantal point processes (DPPs) are rando...  stat
# ...             ...                                                ...   ...
# 35604   1004.5339v3  Debugging of ontologies is an important prereq...    cs
# 10218  1802.03685v2  We present NeuroSAT, a message passing neural ...    cs
# 39187   1411.0802v1  We present an unsupervised framework for simul...    cs
# 6113   1607.06364v1  Distributed learning is the problem of inferri...  stat
# 2243   1710.04924v1  Algorithmic decision making process now affect...  stat
#
#                                                    title  year  \
# 20719  Commonsense Knowledge Enhanced Embeddings for ...  2016
# 3188   Large Scale Variational Bayesian Inference for...  2012
# 9369   CrossCat: A Fully Bayesian Nonparametric Metho...  2015
# 31860       Handling uncertainties in SVM classification  2011
# 11029  Approximate Inference in Continuous Determinan...  2013
# ...                                                  ...   ...
# 35604   Query strategy for sequential ontology debugging  2010
# 10218  Learning a SAT Solver from Single-Bit Supervision  2018
# 39187  Simultaneous Localization, Mapping, and Manipu...  2014
# 6113   Distributed Supervised Learning using Neural N...  2016
# 2243   Two-stage Algorithm for Fairness-aware Machine...  2017
#
#                                                 keywords
# 20719  [commonsense, knowledge, embeddings, disambigu...
# 3188   [statistics, hierarchical, dependencies, repre...
# 9369   [widespread, statistical, dimensional, restric...
# 31860  [addresses, classification, available, uncerta...
# 11029  [determinantal, processes, processes, repulsio...
# ...                                                  ...
# 35604  [debugging, ontologies, important, prerequisit...
# 10218  [classifier, satisfiability, competitive, subs...
# 39187  [unsupervised, framework, simultaneous, appear...
# 6113   [distributed, inferring, distributed, geograph...
# 2243   [algorithmic, classification, regression, appl...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 20719    [commonsense, knowledge, embeddings, disambigu...
# 3188     [statistics, hierarchical, dependencies, repre...
# 9369     [widespread, statistical, dimensional, restric...
# 31860    [addresses, classification, available, uncerta...
# 11029    [determinantal, processes, processes, repulsio...
#                                ...
# 21979    [nonparametric, dirichlet, alternative, underl...
# 34805    [introduced, operating, structured, environmen...
# 3649     [providing, therefore, essential, information,...
# 10612    [biodiversity, monitoring, recordings, achieva...
# 10233    [increasingly, intrusion, detection, capabilit...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8887 words.
# Out of those 4567 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4b8fd4bc-f534-43bc-8b61-c030b4d11528" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b8fd4bc-f534-43bc-8b61-c030b4d11528")) {                    Plotly.newPlot(                        "4b8fd4bc-f534-43bc-8b61-c030b4d11528",                        [{"x":["experiments","achieving","incorporate","therefore","coreference","linguistic","information","resolution","utilization","commonsense","investigate","extraction","conducted","performance","unsupervised","effectiveness","including","embeddings","disambiguation","framework","knowledge","traditional","challenge","effective","estimation","deconvolution","dependencies","algorithm","variational","methodology","inference","inpainting","representing","demonstrate","structured","reconstruction","experimental","statistics","hierarchical","substantially","factorial","approximate","denoising","prediction","approximately","overlapping","analyzing","efficiently","generative","widespread","conditioned","strengths","unemployment","independencies","alternatives","statistical","handwritten","parametric","dimensional","components","nonparametric","competitive","variables","structure","assumptions","representations","predictive","component","empirical","restrictive","dirichlet","measurements","describes","consistent","distributions","independent","heterogeneous","discriminative","expression","consisting","represents","representer","available","objective","quadratic","addresses","outperforms","contribution","estimates","uncertainty","qualitative","insensitive","probability","formulation","performances","uncertainties","classification","considered","associated","predictions","quantitative","posterior","functions","techniques","continuous","tractable","eigendecomposition","repulsion","approximations","repulsive","determinantal","efficient","processes","synthesizing","selection","computationally","organizes","difficult","synthetic","experimentally","complexity","historical","linearity","alternative","providing","numerical","vocabulary","discussed","implementation","overfitting","determine","scalability","increasing","validation","regressors","unfortunately","regressor","computation","applications","stability","polynomial","summarize","piecewise","characteristics","electrocardiograms","intervals","euclidean","segmentation","algorithms","monotonicity","retraining","upsampling","satellite","resolutions","downsampling","locations","applicable","evaluations","convincing","competing","convolutional","generalises","arbitrary","different","respectively","geographical","preserving","virtually","pretraining","stochastic","preconditioned","especially","extremely","parameter","accelerate","pathological","recognition","recurrent","adaptively","preprocessing","requiring","addressing","sensitive","demonstrated","demonstrating","preference","landscapes","hypothesized","mitigating","refinements","significantly","enhancements","surrogate","articulation","candidate","motivation","convergence","characterized","mechanisms","phenomenon"],"y":[598,70,56,134,5,72,713,109,12,5,148,134,96,919,165,198,253,60,19,559,352,162,149,271,197,8,53,809,58,74,208,12,81,549,111,90,358,63,112,34,2,100,42,195,36,23,59,164,126,9,20,19,3,7,27,155,34,46,181,89,15,99,127,345,66,270,58,101,157,6,24,48,84,78,113,124,47,113,50,60,49,2,309,177,28,67,247,71,75,71,50,10,174,82,48,9,539,121,124,74,68,50,224,355,98,28,0,3,33,2,2,386,98,7,176,76,2,146,126,50,234,17,8,109,95,80,31,47,133,31,69,27,112,52,6,27,11,133,424,48,69,17,10,88,2,19,30,202,549,5,9,6,11,15,4,36,45,58,6,33,396,2,86,746,90,11,56,8,3,122,0,141,55,124,22,4,411,142,18,31,33,27,51,101,33,19,7,6,9,1,273,6,14,7,51,17,121,28,51,28],"type":"bar"},{"x":["experiments","achieving","inco ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4567,), (4567, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style=''>Plant</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style=''>Solving</span> <span style=''>Economic</span> <span style=''>Load</span> <span style=''>Dispatch</span> <span style=''>Problem</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>design</span> <span style='background-color:rgba(0, 255, 0, 0.43209876543209874);'>engineering</span> <span style=''>are</span> <span style=''>complex</span> <span style=''>by</span> <span style=''>nature</span> <span style=''>often</span> <span style=''>because</span> <span style=''>of</span> <span style=''>the</span> <span style=''>involvement</span> <span style=''>of</span> <span style=''>critical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>accompanied</span> <span style=''>by</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>rigid</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>the</span> <span style=''>products</span> <span style=''>involved</span> <span style=''>One</span> <span style=''>such</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>Economic</span> <span style=''>Load</span> <span style=''>Dispatch</span> <span style=''>(ED)</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>focuses</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style=''>the</span> <span style=''>fuel</span> <span style=''>cost</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satisfying</span> <span style=''>some</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Classical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sufficient</span> <span style=''>and</span> <span style=''>also</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inefficient</span> <span style=''>for</span> <span style=''>the</span> <span style=''>ED</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>involving</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.313953488372093);'>nonlinear</span> <span style=''>and</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>both</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>and</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>This</span> <span style=''>led</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4966887417218542);'>development</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>metaheuristic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>which</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style=''>Adaptive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style=''>Filter</span> <br/><br/><span style=''>We</span> <span style=''>use</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>an</span> <span style=''>adaptive</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>systems</span> <span style=''>Optimal</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Kalman</span> <span style=''>filter</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style=''>systems</span> <span style=''>process</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurement</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>that</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainties</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>from</span> <span style=''>(conditioned</span> <span style=''>on)</span> <span style=''>past</span> <span style=''>observed</span> <span style=''>data</span> <span style=''>and</span> <span style=''>without</span> <span style=''>making</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>systems</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>The</span> <span style=''>systems</span> <span style=''>prior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>at</span> <span style=''>each</span> <span style=''>time</span> <span style=''>step</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>from</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>of</span> <span style=''>least</span> <span style=''>squares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>on</span> <span style=''>sub</span> <span style=''>sampled</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>jackknife</span> <span style=''>sampling</span> <span style=''>As</span> <span style=''>new</span> <span style=''>data</span> <span style=''>is</span> <span style=''>acquired</span> <span style=''>the</span> <span style=''>state</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurement</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>are</span> <span style=''>updated</span> <span style='background-co ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>ell</span> <span style=''>1</span> <span style='background-color:rgba(255, 0, 0, 0.31677018633540377);'>regularized</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Improperly</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Learnable</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Polynomial</span> <span style=''>Time</span> <br/><br/><span style=''>We</span> <span style=''>study</span> <span style=''>the</span> <span style=''>improper</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>layer</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Suppose</span> <span style=''>that</span> <span style=''>the</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>to</span> <span style=''>be</span> <span style=''>learned</span> <span style=''>has</span> <span style=''>k</span> <span style=''>hidden</span> <span style=''>layers</span> <span style=''>and</span> <span style=''>that</span> <span style=''>the</span> <span style=''>ell</span> <span style=''>1</span> <span style=''>norm</span> <span style=''>of</span> <span style=''>the</span> <span style=''>incoming</span> <span style=''>weights</span> <span style=''>of</span> <span style=''>any</span> <span style=''>neuron</span> <span style=''>is</span> <span style=''>bounded</span> <span style=''>by</span> <span style=''>L</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>method</span> <span style=''>such</span> <span style=''>that</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probability</span> <span style=''>at</span> <span style=''>least</span> <span style=''>1</span> <span style=''>delta</span> <span style=''>it</span> <span style=''>learns</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictor</span> <span style=''>whose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>is</span> <span style=''>at</span> <span style=''>most</span> <span style=''>epsilon</span> <span style=''>worse</span> <span style=''>than</span> <span style=''>that</span> <span style=''>of</span> <span style=''>the</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>The</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>and</span> <span style=''>the</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3639846743295018);'>presented</span> <span style=''>method</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>in</span> <span style=''>the</span> <span style=''>input</span> <span style='background-color:rgba(255, 0, 0, 0.4653465346534654);'>dimension</span> <span style=''>and</span> <span style=''>in</span> <span style=''>(1epsilonlog(1delta)F(kL))</span> <span style=''>where</span> <span style=''>F(kL)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>(kL)</span> <span style=''>and</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>activation</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Improving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>in</span> <span style=''>Models</span> <span style=''>With</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Continuous</span> <span style=''>Symmetry</span> <span style=''>Breaking</span> <br/><br/><span style=''>Many</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>learning</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>invariant</span> <span style=''>under</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>symmetry</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformation</span> <span style=''>As</span> <span style=''>an</span> <span style=''>example</span> <span style=''>consider</span> <span style=''>word</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>(Mikolov</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2013)</span> <span style=''>where</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>remains</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unchanged</span> <span style=''>if</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simultaneously</span> <span style=''>rotate</span> <span style=''>all</span> <span style=''>word</span> <span style=''>and</span> <span style=''>context</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>vectors</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representation</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>symmetry</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Markovian</span> <span style=''>time</span> <span style=''>series</span> <span style=''>prior</span> <span style=''>possess</span> <span style=''>so</span> <span style=''>called</span> <span style=''>Goldstone</span> <span style=''>modes</span> <span style=''>These</span> <span style=''>are</span> <span style=''>low</span> <span style=''>cost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deviations</span> <span style=''>from</span> <span style=''>the</span> <span style=''>optimum</span> <span style=''>which</span> <span style=''>slow</span> <span style=''>down</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>of</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>We</span> <span style=''>use</span> <span style=''>tools</span> <span style=''>from</span> <span style=''>gauge</span> <span style=''>theory</span> <span style=''>in</span> <span style=''>physics</span> <span style=''>to</span> <span style=''>design</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>solves</span> <span style=''>the</span> <span style=''>slow</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>problem</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>decay</span> <span style=''>of</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12566940378436273)
# 	architecture (0.08961085326669047)
# 	representation (0.1299535880042842)
# 	processing (0.10746162084969654)
# 	segmentation (0.07211710103534452)
# 	information (0.2545519457336666)
# 	detection (0.1203141735094609)
# 	different (0.26633345233845057)
# 	convolutional (0.14137807925740806)
# 	recognition (0.1467333095323099)
#
# Some Statistics words are:
# 	stochastic (0.1310655327663832)
# 	statistical (0.14757378689344672)
# 	variables (0.13906953476738368)
# 	theoretical (0.15507753876938468)
# 	estimation (0.16758379189594796)
# 	algorithm (0.39119559779889945)
# 	distribution (0.18859429714857429)
# 	dimensional (0.18359179589794897)
# 	inference (0.2001000500250125)
# 	regression (0.19109554777388693)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="57588a84-b8da-4602-935c-d3e3d83b0fb0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57588a84-b8da-4602-935c-d3e3d83b0fb0")) {                    Plotly.newPlot(                        "57588a84-b8da-4602-935c-d3e3d83b0fb0",                        [{"x":["experiments","achieving","incorporate","therefore","coreference","linguistic","information","resolution","utilization","commonsense","investigate","extraction","conducted","performance","unsupervised","effectiveness","including","embeddings","disambiguation","framework","knowledge","traditional","challenge","effective","estimation","deconvolution","dependencies","algorithm","variational","methodology","inference","inpainting","representing","demonstrate","structured","reconstruction","experimental","statistics","hierarchical","substantially","factorial","approximate","denoising","prediction","approximately","overlapping","analyzing","efficiently","generative","widespread","conditioned","strengths","unemployment","independencies","alternatives","statistical","handwritten","parametric","dimensional","components","nonparametric","competitive","variables","structure","assumptions","representations","predictive","component","empirical","restrictive","dirichlet","measurements","describes","consistent","distributions","independent","heterogeneous","discriminative","expression","consisting","represents","representer","available","objective","quadratic","addresses","outperforms","contribution","estimates","uncertainty","qualitative","insensitive","probability","formulation","performances","uncertainties","classification","considered","associated","predictions","quantitative","posterior","functions","techniques","continuous","tractable","eigendecomposition","repulsion","approximations","repulsive","determinantal","efficient","processes","synthesizing","selection","computationally","organizes","difficult","synthetic","experimentally","complexity","historical","linearity","alternative","providing","numerical","vocabulary","discussed","implementation","overfitting","determine","scalability","increasing","validation","regressors","unfortunately","regressor","computation","applications","stability","polynomial","summarize","piecewise","characteristics","electrocardiograms","intervals","euclidean","segmentation","algorithms","monotonicity","retraining","upsampling","satellite","resolutions","downsampling","locations","applicable","evaluations","convincing","competing","convolutional","generalises","arbitrary","different","respectively","geographical","preserving","virtually","pretraining","stochastic","preconditioned","especially","extremely","parameter","accelerate","pathological","recognition","recurrent","adaptively","preprocessing","requiring","addressing","sensitive","demonstrated","demonstrating","preference","landscapes","hypothesized","mitigating","refinements","significantly","enhancements","surrogate","articulation","candidate","motivation","convergence","characterized","mechanisms","phenomenon","searching","evolutionary","practical","incorporation","approaches","emergence","strategies","contributions","promising","accordingly","evolution","expensive","algorithmic","solutions","leveraging","considerable","estimating","regularized","augmenting","undirected","attracted","difficulty","neighborhood","importance","extending","probabilistic","additionally","introduce","attention","graphical","processing","computational","stratifying","clinically","covariates","developing","according","corresponding","specifically","actionable","unprecedented","physicians","opportunity","validated","electronic","observations","objectives","important","misbehaving","appropriate","formulations","sw ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	eigendecomposition
# 	preconditioned
# 	stratifying
# 	confounders
# 	semiparametric
# 	nonparanormal
# 	criticisms
# 	definiteness
# 	diffusing
# 	thresholded
# 	amortization
# 	simulators
# 	sophistication
# 	stagewise
# 	initialise
# 	forecasted
# 	penetration
# 	preconditioning
# 	precisions
# 	whitening
# Some words which never appear in Statistics papers:
# 	coreference
# 	commonsense
# 	unemployment
# 	organizes
# 	electrocardiograms
# 	upsampling
# 	downsampling
# 	virtually
# 	hypothesized
# 	articulation
# 	misbehaving
# 	anticipated
# 	decidability
# 	homomorphism
# 	forthcoming
# 	differentiated
# 	transducer
# 	algebraically
# 	photographs
# 	refractive

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0696503668232195e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7683333333333333
